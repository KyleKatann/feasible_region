# %%
# %matplotlib inline
import feasible_region
import sympy as sym
x,y=sym.symbols("x y")
u=feasible_region.model()
u.linspace(0,5,6)
u.spacelimit(0,5,0,5)
u.addConstr(-1*x + 2*y - 4)
u.addConstr(5*x + y - 20)
u.addConstr(-2*x - 2*y + 7)
u.addConstr(-x+2 )
u.addConstr( y - 4)
u.show()
# Out:
# おまじない   :import sympy as sym
#              x,y=sym.symbols(x y)
# .model      :feasoble_resion.model()
# .linspace   :x始まり座標、x終わり座標、左二つの分割
# .spacelimit :x始まり座標、x終わり座標、y始まり座標、y終わり座標
# .addConstr  :例 -1*x+2*y-88 など、x-4,y-6などの式も可
#              変数はx、yのみ
#              等号は判定できないのですべて左辺へ移行すること
# .show       :plt.show()と同じ
